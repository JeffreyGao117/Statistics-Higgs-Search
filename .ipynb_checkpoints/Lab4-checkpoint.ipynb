# %% [markdown]
# # Lab 4

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import h5py

#this sets the size of the plot to something useful
plt.rcParams["figure.figsize"] = (20,15)
hf = h5py.File('../gammaray_lab4.h5', 'r')
hf.keys()

# time (in gps seconds), Solar phase (deg), Earth longitude (deg), and gamma-ray counts
data = np.array(hf.get('data'))
hf.close()

# %% [markdown]
# ## Problem 1
#
# In this problem we are looking at the data from a gamma-ray satellite orbiting in low Earth orbit. It takes a reading of the number of particles detected every 100 milliseconds, and is in an approximately 90 minute orbit. While it is looking for gamma-ray bursts, virtually all of the particles detected are background cosmic rays.
#
# __1)__
#
# The solar phase and Earth longitude oscillate and do not vary much with time. The number of counts average at around 10 but occasionally spike to a higher/lower number of particles. Looking at plot 5, we can see that there are spikes over a range of solar phase. From homework 3, I could fold the time variable to see if it presents a pattern from the data. With plot 6, there is some no distinct indication of where spikes occur relative to the longitude but do occur more frequently at higher longitudes over the Pacific ocean. Another method is to aggregate the particle counts with a range of solar phase or longitude and compare data within those specific periods.
#
# __2)__
#
# The background shifts with longitude and solar phase with an increased number of counts at the start of a cycle and then gradually decreases until the next cycle. We can see that the cosmic ray counts are more consistent with the solar phase than with Earth's longitude.

# %%
#----- Examining Data
fig1, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(15,15))

time = data[0][0:-1:10000]
print(np.max(time), np.min(time))
phase = data[1][0:-1:10000]
print(np.max(phase), np.min(phase))
longt = data[2][0:-1:10000]
print(np.max(longt), np.min(longt))
counts = data[3][0:-1:10000]

# ax1.plot(data[0][0:100000:10], data[1][0:100000:10])  # solar phase
# ax2.plot(data[0][0:100000:10], data[2][0:100000:10])  # longitude
ax1.plot(time, counts)

ax2.plot(time[0:1000], counts[0:1000])
temp = ax2.twinx()
temp.plot(time[0:1000], phase[0:1000], 'r', alpha = 0.3)

ax3.plot(time[0:10000:10], counts[0:10000:10])
temp = ax3.twinx()
temp.plot(time[0:10000:10], longt[0:10000:10], 'g', alpha=0.3)

# Does not work as background because there is still noise in this data
ax4.hist(counts, bins=20)
ax4.set_yscale('log', nonposy='clip')

plt.show()
# Out:
# 943271016.0 940680016.0
# 359.92026748970966 0.03330761316465214
# 351.6666666666715 5.0

# %% [markdown]
# Here we see that the background distribution mostly follows that of a Poisson. This still includes signals so we will now remove them.

# %%
#----- Separating Data
# We would want to know for each cycle, how the counts change relative to the satellite's position around the Earth(longitude)

find_longt = np.where(data[2][0:1000000] <= 0.01)[0]  # Arbitrary length; just enough to find a consistent cycle length
delta2 = []
for n in range(len(find_longt)-1):
    diff = find_longt[n+1]-find_longt[n]
    if diff != 1:
        delta2.append(diff)
print(np.average(delta2))
longt_cycle = 53999
# Out:
# 53999.0

# %%
# Separating into single cycles
def reshape(lst, n):
    return [lst[i*n:(i+1)*n] for i in range((len(lst)+n-1)//n)]

longt_counts = reshape(data[3][0:-1], longt_cycle)  # Designates the amount of data to be cut into cycles
longt_time = reshape(data[0][0:-1], longt_cycle)

# %%
# Split longitude cycles into 18 20-degree sections
split_ltcounts = []
for n in range(len(longt_counts)):
    split_ltcounts.append(np.array_split(longt_counts[n], 18))  # [[18 sections], [18 sections], [], []]

# Arrange 20-degree longitude sections into groups of corresponding degree
arranged = [[] for n in range(18)]
for n in range(len(longt_counts)):
    for j in range(18):
        arranged[j].append(split_ltcounts[n][j])

# Combining sections into single array
combined = [[] for n in range(18)]
for n in range(len(arranged)):
    for j in range(len(arranged[n])):
        combined[n].extend(arranged[n][j])

# %%
# Remove data in each section(all cycles) that exceed 5 standard deviations above the mean
averages = []
for section in combined:
    std = np.std(section)
    avg = np.average(section)
    averages.append(avg)
    sig = avg + 5 * std
    for n in section:
        if n > sig:
            section.remove(n)

# %%
fig2, (ax1, ax2) = plt.subplots(2, 1, figsize=(15,10))

rms = stats.poisson(averages[0]).rvs(longt_cycle)
space = int(len(combined[0])/longt_cycle)
ax1.hist(combined[0][0:-1:space], 22, alpha=0.4, color='g')  # Data
ax1.hist(rms, 22, alpha=0.4, color='r')  # Model
temp = ax1.twinx()
x = np.arange(stats.poisson.ppf(0.01, averages[0]), stats.poisson.ppf(0.99, averages[0]))
temp.step(x, stats.poisson.pmf(x, averages[0]))
ax1.set_title('Data and model Poisson distributions')

for section in combined:
    ax2.hist(section, 21, alpha=0.4)
ax2.set_yscale('log')
ax2.set_title('Grouped cosmic rays counts over longitude range')

plt.show()

# %% [markdown]
# __3)__
#
# Over the range of 5 to ~352 degree longitude, the average cosmic ray count shifts from ~10.3 to ~5.8 each cycle. The modeled background is slightly higher overall than the data but matches the shape and variance of the data.
#
# __4)__
#
# For a 100 ms GRB, we get a threshold of:
# <!--100 milliseconds = 100,000 microseconds; time data recorded in microseconds.-->

# %%
prob = 1 - stats.norm.cdf(5)
for mean in averages:
    print('Mean: ', mean, ' Threshold: ', stats.poisson.ppf(1 - prob, mean))
# Out:
# Mean:  7.616061365516063  Threshold:  25.0
# Mean:  7.227294349342061  Threshold:  24.0
# Mean:  6.923945176027949  Threshold:  24.0
# Mean:  6.682161515027149  Threshold:  23.0
# Mean:  6.484969379046365  Threshold:  23.0
# Mean:  6.329573681604581  Threshold:  22.0
# Mean:  6.201927463860053  Threshold:  22.0
# Mean:  6.101697398729329  Threshold:  22.0
# Mean:  6.023720388576048  Threshold:  22.0
# Mean:  5.956054990635592  Threshold:  22.0
# Mean:  5.907448263122844  Threshold:  22.0
# Mean:  5.867792062232167  Threshold:  21.0
# Mean:  5.832436358787966  Threshold:  21.0
# Mean:  8.046444994743151  Threshold:  26.0
# Mean:  10.347143732127059  Threshold:  30.0
# Mean:  9.425507595001758  Threshold:  28.0
# Mean:  8.687642445344737  Threshold:  27.0
# Mean:  8.090006154718223  Threshold:  26.0

# %% [markdown]
# ## Problem 2
# - transient: find something in 1 image but not the others; differentiate images
# - both: how to get signal-free background for one image; unknown tails in distribution
# - might not find the signal
#
# In this problem we are going to look at a stack of telescope images (again simulated). We have 10 images, but you and your lab partner will be looking for different signals. One of you will be looking for the faintest stars, while the other will be looking for a transient (something like a super novae that only appears in one image). Flip a coin to determine which of you is pursuing which question.

# %%
hf = h5py.File('../images.h5', 'r')
hf.keys()
imagestack = np.array(hf.get('imagestack'))
hf.close()
print(data.shape)
# Out:
# (200, 200, 10)

# %%
fig3, (ax1, ax2) = plt.subplots(2, 1, figsize=(10,10))

# First Image
x1 = np.sum(imagestack[:,:,0], 0)
y1 = np.sum(imagestack[:,:,0], 1)
ax1.hist2d(x1, y1, 30)

# PDF
x = np.mean(imagestack, axis=2).flatten()
ax2.hist(x, 1000, density=True)
ax2.set_yscale('log')
x=x[x<15]
avg = np.mean(x)
std = np.std(x)
print(avg, std)
xlin = np.linspace(-5,5,1000)
temp = ax2.twinx()
temp.plot(xlin, stats.norm.pdf(xlin, avg, std), 'r')

plt.show()
# Out:
# 0.013727278976052814 0.3899943057478965

# %% [markdown]
# 2) Explore the data. Is there signal contamination? Is the background time dependent? Is it consistent spatially? Develop a plan to calculate your background pdf().
#
# We see that the x-distribution of a single image follows a Gaussian and does contain signal contamination. The background does not seem time dependent as the distributions for each image still follow that of a Gaussian without much deviation. The spacing does not appear to be consistent and the background spreads over an increasing x-value.

# %%
images = []
for n in range(10):
    images.append(imagestack[:,:,n].flatten())

prob = 1 - stats.norm.cdf(5)
threshold = stats.norm.ppf(1 - prob, avg, std)
print('Threshold: ', threshold)

# Find all significant signals
sigf = [[] for n in range(10)]
allsig = []
for n in range(10):
    print(np.var(images[n]))
    for j in images[n]:
        if j > threshold:
            sigf[n].append(j)
            allsig.append(j)

# 0 46.01175269422071
# 0 42.8160311273187
# 0 45.282068177176185
# 1 40.83313569396426
# 1 46.592267064916705
# 1 42.61082301950937
# 1 45.40146834423952
# 2 47.79010819628649
# 2 42.959733189261904
# 2 44.14834099587788
# 3 46.081120603006916
# 3 44.204998239460664
# 3 45.18667646999015
# 4 47.0003865702652
# 4 43.64881856074571
# 4 45.65562118904107
# 5 46.621316029297525
# 5 43.72911976789589
# 5 45.35362691164617
# 6 46.99131843066182
# 6 42.406339924465755
# 6 45.04720791636413
# 7 47.26324939630629
# 7 42.459411061708174
# 7 45.328751897591836
# 8 46.4883943499121
# 8 42.35307313979401
# 8 45.72891215392458
# 9 47.21296880302628
# 9 43.31786361099631
# 9 45.41674660852361

# Of all 5-sig
avg1 = np.mean(allsig)
std1 = np.std(allsig)
print(avg1, std1)
# Out:
# Threshold:  1.9636988077039041
# 0.981945124214117
# 0.9859444490986283
# 0.983666019010812
# 0.9817122989636861
# 0.9833101170646394
# 0.9827672991489024
# 0.9761242724816095
# 0.9822577785236887
# 0.9753324336721948
# 0.9848674375364226
# 11.152296559063437 9.878857284604008

# %% [markdown]
# 3) Using your background distribution, hunt for a transient. Describe what you find.
#
# To find a transient, we can find the image with the highest density assuming these images indicate luminosity. The differences between each image can be compared to find the one with 5$\sigma$ on a right-tailed test relative to the other stars. From looking at the signals with 5$\sigma$, there are a multiple signals that correspond to the largest value. In exploring these values, the largest signal is in the second picture with 47.79.
#
# 4) You and your lab partner had different pdf(), but were using the same data. Explore why this is.
#
# We are looking for different signals, one to find the faintest stars and the other to find transients. These require different methods. My lab partner used a trials factor to average and then filter the stars while I am comparing the differences between image to find the "correct" image.
